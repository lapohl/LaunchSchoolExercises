# %%
import praw

reddit = praw.Reddit(
    client_id="aOA0-iKeVnl33Q",
    client_secret="7DRTigNcNqcGCIKDG92zSCmab2gSpA",
    user_agent="test by nomnomeste",
    username="nomnomeste",
    password="eNgiNes1!",
)
print(reddit.user.me())
print(reddit.read_only)
# Output: False
# Out:
# nomnomeste
# False

# %%
import pprint

author_comment = []
body_comment = []
top_id_comment = []
new_comments = {}

for post in reddit.subreddit('pickleball').new(limit = 50):

    for comment in post.comments:
        print(comment.author)
        author_comment.append(comment.author)
        body_comment.append(comment.body)
        top_id_comment.append(comment.parent_id)
# Out:
# VonLudwig
# kingkev115
# soundwithdesign
# canadave_nyc
# SheasCode
# Teh_Hipster
# HalobenderFWT
# Teh_Hipster
# cleaverfirewok
# Nevets77-
# dontfightthehood
# cleaverfirewok
# AJ651
# ECM_ECM
# soundwithdesign
# teqogan
# MinisterOfMuggles
# SCCODER
# Verdiii
# No-Captain-3381
# SirSneezALot
# monsterturtlebot
# soundwithdesign
# Destincrlist
# brunkeberg
# Fitzy564
# harveyfb4
# Gilbert_AZ
# gaming-is-life
# day2dayliving
# MedicineRiver
# BecomeARealHuman
# ScotchBarrel
# Sure-Instruction-164
# crewbaka
# Steadi
# kimster13579
# BeardedBatsard
# Charming-News-7665
# Tommypickleball
# douginpaso
# OnlyControlYourself
# vectorscopexy
# Krescan
# sygon5
# CrapPlasma48
# Bluebaronn
# GooBengie
# JezasLe4f
# gunnz63
# tealcosmo
# AirbladeOrange
# DudusMaximus8
# Sure-Instruction-164
# caiccdisciple
# mtnb1k3r
# Icreatedthis4u
# Wandering-Sparrow
# pck313
# Salt_Transition_1424
# dsm09e
# day2dayliving
# Individual_System806
# mtnb1k3r
# PerfectlyPowerful
# teqogan
# pck313
# ...
